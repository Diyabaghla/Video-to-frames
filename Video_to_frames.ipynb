# %% [markdown]
# <a href="https://colab.research.google.com/github/Diyabaghla/Video-to-frames/blob/main/Video_to_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
from google.colab.patches import cv2_imshow
#from google.colab import files

# Read the video from specified path
cam = cv2.VideoCapture("video.mp4")

try:

    # creating a folder named data
    if not os.path.exists('data'):
        os.makedirs('data')

# if not created then raise error
except OSError:
    print ('Error: Creating directory of data')

 # frame
currentframe = 0

while(True):

    # reading from frame
    ret,frame = cam.read()

    if ret:
        # if video is still left continue creating images
        name = str(currentframe) + '.jpg'
        print ('Creating...' + name)
        #to display the frames in output
        #cv2_imshow(frame)

        # writing the extracted images
        cv2.imwrite(name, frame)


        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
       # cv2.imwrite('data',frame)

    else:
        break

# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating...0.jpg
# Creating...1.jpg
# Creating...2.jpg
# Creating...3.jpg
# Creating...4.jpg
# Creating...5.jpg
# Creating...6.jpg
# Creating...7.jpg
# Creating...8.jpg
# Creating...9.jpg
# Creating...10.jpg
# Creating...11.jpg
# Creating...12.jpg
# Creating...13.jpg
# Creating...14.jpg
# Creating...15.jpg
# Creating...16.jpg
# Creating...17.jpg
# Creating...18.jpg
# Creating...19.jpg
# Creating...20.jpg
# Creating...21.jpg
# Creating...22.jpg
# Creating...23.jpg
# Creating...24.jpg
# Creating...25.jpg
# Creating...26.jpg
# Creating...27.jpg
# Creating...28.jpg
# Creating...29.jpg
# Creating...30.jpg
# Creating...31.jpg
# Creating...32.jpg
# Creating...33.jpg
# Creating...34.jpg
# Creating...35.jpg
# Creating...36.jpg
# Creating...37.jpg
# Creating...38.jpg
# Creating...39.jpg
# Creating...40.jpg
# Creating...41.jpg
# Creating...42.jpg
# Creating...43.jpg
# Creating...44.jpg
# Creating...45.jpg
# Creating...46.jpg
# Creating...47.jpg
# Creating...48.jpg
# Creating...49.jpg
# Creating...50.jpg
# Creating...51.jpg
# Creating...52.jpg
# Creating...53.jpg
# Creating...54.jpg
# Creating...55.jpg
# Creating...56.jpg
# Creating...57.jpg
# Creating...58.jpg
# Creating...59.jpg
# Creating...60.jpg
# Creating...61.jpg
# Creating...62.jpg
# Creating...63.jpg
# Creating...64.jpg
# Creating...65.jpg
# Creating...66.jpg
# Creating...67.jpg
# Creating...68.jpg
# Creating...69.jpg
# Creating...70.jpg
# Creating...71.jpg
# Creating...72.jpg
# Creating...73.jpg
# Creating...74.jpg
# Creating...75.jpg
# Creating...76.jpg
# Creating...77.jpg
# Creating...78.jpg
# Creating...79.jpg
# Creating...80.jpg
# Creating...81.jpg
# Creating...82.jpg
# Creating...83.jpg
# Creating...84.jpg
# Creating...85.jpg
# Creating...86.jpg
# Creating...87.jpg
# Creating...88.jpg
# Creating...89.jpg
# Creating...90.jpg
# Creating...91.jpg
# Creating...92.jpg
# Creating...93.jpg
# Creating...94.jpg
# Creating...95.jpg
# Creating...96.jpg
# Creating...97.jpg
# Creating...98.jpg
# Creating...99.jpg
# Creating...100.jpg
# Creating...101.jpg
# Creating...102.jpg
# Creating...103.jpg
# Creating...104.jpg
# Creating...105.jpg
# Creating...106.jpg
# Creating...107.jpg
# Creating...108.jpg
# Creating...109.jpg
# Creating...110.jpg
# Creating...111.jpg
# Creating...112.jpg
# Creating...113.jpg
# Creating...114.jpg
# Creating...115.jpg
# Creating...116.jpg
# Creating...117.jpg
# Creating...118.jpg
# Creating...119.jpg
# Creating...120.jpg
# Creating...121.jpg
# Creating...122.jpg
# Creating...123.jpg
# Creating...124.jpg
# Creating...125.jpg
# Creating...126.jpg
# Creating...127.jpg
# Creating...128.jpg
# Creating...129.jpg
# Creating...130.jpg
# Creating...131.jpg
# Creating...132.jpg
# Creating...133.jpg
# Creating...134.jpg
# Creating...135.jpg
# Creating...136.jpg
# Creating...137.jpg
# Creating...138.jpg
# Creating...139.jpg
# Creating...140.jpg
# Creating...141.jpg
# Creating...142.jpg
# Creating...143.jpg
# Creating...144.jpg
# Creating...145.jpg
# Creating...146.jpg
# Creating...147.jpg
# Creating...148.jpg
# Creating...149.jpg
# Creating...150.jpg
# Creating...151.jpg
# Creating...152.jpg
# Creating...153.jpg
# Creating...154.jpg
# Creating...155.jpg
# Creating...156.jpg
# Creating...157.jpg
# Creating...158.jpg
# Creating...159.jpg
# Creating...160.jpg
# Creating...161.jpg
# Creating...162.jpg
# Creating...163.jpg
# Creating...164.jpg
# Creating...165.jpg
# Creating...166.jpg
# Creating...167.jpg
# Creating...168.jpg
# Creating...169.jpg
# Creating...170.jpg
# Creating...171.jpg
# Creating...172.jpg
# Creating...173.jpg
# Creating...174.jpg
# Creating...175.jpg
# Creating...176.jpg
# Creating...177.jpg
# Creating...178.jpg
# Creating...179.jpg
# Creating...180.jpg
# Creating...181.jpg
# Creating...182.jpg
# Creating...183.jpg
# Creating...184.jpg
# Creating...185.jpg
# Creating...186.jpg
# Creating...187.jpg
# Creating...188.jpg
# Creating...189.jpg
# Creating...190.jpg
# Creating...191.jpg
# Creating...192.jpg
# Creating...193.jpg
# Creating...194.jpg
# Creating...195.jpg
# Creating...196.jpg
# Creating...197.jpg
# Creating...198.jpg
# Creating...199.jpg
# Creating...200.jpg
# Creating...201.jpg
# Creating...202.jpg
# Creating...203.jpg
# Creating...204.jpg
# Creating...205.jpg
# Creating...206.jpg
# Creating...207.jpg
# Creating...208.jpg
# Creating...209.jpg
# Creating...210.jpg
# Creating...211.jpg
# Creating...212.jpg
# Creating...213.jpg
# Creating...214.jpg
# Creating...215.jpg
# Creating...216.jpg
# Creating...217.jpg
# Creating...218.jpg
# Creating...219.jpg
# Creating...220.jpg
# Creating...221.jpg
# Creating...222.jpg
# Creating...223.jpg
# Creating...224.jpg
# Creating...225.jpg
# Creating...226.jpg
# Creating...227.jpg
# Creating...228.jpg
# Creating...229.jpg
# Creating...230.jpg
# Creating...231.jpg
# Creating...232.jpg
# Creating...233.jpg
# Creating...234.jpg
# Creating...235.jpg
# Creating...236.jpg
# Creating...237.jpg
# Creating...238.jpg
# Creating...239.jpg
# Creating...240.jpg

# %%
import shutil
from google.colab import files

# Define the folder to be zipped
folder_to_zip = '/content/data'  # replace 'your_folder' with your folder name

# Define the name of the output zip file
output_filename = '/content/data.zip'  # replace 'your_folder.zip' with your desired zip file name

# Zip the folder
shutil.make_archive(output_filename.replace('.zip', ''), 'zip', folder_to_zip)

# Download the zip file
files.download(output_filename)
